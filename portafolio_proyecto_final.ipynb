# %% [markdown]
# <a href="https://colab.research.google.com/github/jovanneconde/simulacion-II/blob/main/portafolio_proyecto_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
import yfinance as yf

# Especifica el símbolo de la acción y el rango de fechas
symbol = 'MSFT', 'AMZN', 'TSLA', 'PG', 'SPOT'
start_date = '2020-01-01'
end_date ='2021-01-01'

# Utiliza yfinance para obtener los datos de Yahoo Finance
stocks = yf.download(symbol, start=start_date,end=end_date)['Adj Close']

# Muestra los primeros registros de los datos
print(data.head())
# Out:
# [*********************100%***********************]  5 of 5 completed
#                  AMZN        MSFT          PG       SPOT        TSLA
# Date
# 2023-01-03  85.820000  238.460144  149.687668  81.900002  108.099998
# 2023-01-04  85.139999  228.029129  150.339447  81.330002  113.639999
# 2023-01-05  83.120003  221.270844  148.472931  81.580002  110.339996
# 2023-01-06  86.080002  223.878601  152.008469  83.540001  113.059998
# 2023-01-09  87.360001  226.058380  150.151810  85.040001  119.769997

# %%
(stocks/stocks.iloc[0]*100).plot(figsize=(10,10))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def calcular_retornos(stocks):
  return stocks.pct_change()

# %%
retornos=calcular_retornos(stocks)
retornos.dropna()
retornos.sum()
# Out:
# AMZN    0.614203
# MSFT    0.432721
# PG      0.196788
# SPOT    0.881220
# TSLA    2.513301
# dtype: float64

# %%
retornos
# Out:
#                 AMZN      MSFT        PG      SPOT      TSLA
# Date
# 2020-01-02       NaN       NaN       NaN       NaN       NaN
# 2020-01-03 -0.012139 -0.012452 -0.006725  0.005804  0.029633
# 2020-01-06  0.014886  0.002585  0.001387  0.027672  0.019255
# 2020-01-07  0.002092 -0.009118 -0.006191 -0.004467  0.038801
# 2020-01-08 -0.007809  0.015928  0.004263  0.017690  0.049205
# ...              ...       ...       ...       ...       ...
# 2020-12-24 -0.003949  0.007827  0.010122 -0.007255  0.024443
# 2020-12-28  0.035071  0.009922  0.006970 -0.033801  0.002901
# 2020-12-29  0.011584 -0.003601 -0.001875  0.003593  0.003466
# 2020-12-30 -0.010882 -0.011019 -0.004696  0.002889  0.043229
# 2020-12-31 -0.008801  0.003338  0.009944 -0.014686  0.015674
#
# [253 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_4979315387158421663 = autoviz.get_registered_df('df_4979315387158421663')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_4979315387158421663, *['AMZN'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_4069770288954867921 = autoviz.get_registered_df('df_4069770288954867921')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_4069770288954867921, *['MSFT'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_154790292078802645 = autoviz.get_registered_df('df_154790292078802645')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_154790292078802645, *['PG'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_9177504130651184132 = autoviz.get_registered_df('df_9177504130651184132')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_9177504130651184132, *['SPOT'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_3732692622547615180 = autoviz.get_registered_df('df_3732692622547615180')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_3732692622547615180, *['AMZN'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_3485294187554975032 = autoviz.get_registered_df('df_3485294187554975032')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_3485294187554975032, *['MSFT'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6320601399818903437 = autoviz.get_registered_df('df_6320601399818903437')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_6320601399818903437, *['PG'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6025602507776746523 = autoviz.get_registered_df('df_6025602507776746523')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_6025602507776746523, *['SPOT'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_36165880948774878 = autoviz.get_registered_df('df_36165880948774878')
#
# def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
#     plt.xlabel(x_colname)
#     plt.ylabel(y_colname)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df_36165880948774878, *[[['AMZN', 'MSFT'], ['MSFT', 'PG'], ['PG', 'SPOT'], ['SPOT', 'TSLA']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_5520710557366045245 = autoviz.get_registered_df('df_5520710557366045245')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3)):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   def _plot_series(series, series_name):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name)
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for series_name, series in df.groupby(series_colname):
#       _plot_series(series, series_name)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_5520710557366045245, *['Date', 'AMZN', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2535390665680515233 = autoviz.get_registered_df('df_2535390665680515233')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3)):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   def _plot_series(series, series_name):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name)
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for series_name, series in df.groupby(series_colname):
#       _plot_series(series, series_name)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_2535390665680515233, *['Date', 'MSFT', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_5469174074560636533 = autoviz.get_registered_df('df_5469174074560636533')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3)):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   def _plot_series(series, series_name):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name)
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for series_name, series in df.groupby(series_colname):
#       _plot_series(series, series_name)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_5469174074560636533, *['Date', 'PG', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7798492256602478587 = autoviz.get_registered_df('df_7798492256602478587')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3)):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   def _plot_series(series, series_name):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name)
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for series_name, series in df.groupby(series_colname):
#       _plot_series(series, series_name)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_7798492256602478587, *['Date', 'SPOT', None], **{})
# chart

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def retorno_log(stocks):
  return np.log(stocks) - np.log(stocks.shift(1))

# %%
log_retornos=retorno_log(stocks)
log_retornos.dropna()
log_retornos.sum()
# Out:
# AMZN    0.539979
# MSFT    0.336064
# PG      0.144367
# SPOT    0.730115
# TSLA    2.104196
# dtype: float64

# %%
log_retornos.sum().mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of AMZN    0.539979
# MSFT    0.336064
# PG      0.144367
# SPOT    0.730115
# TSLA    2.104196
# dtype: float64>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Asignacion de pesos de manera aleatoria

# %%
num_stocks = len(list_stocks)
random_array=np.random.random(num_stocks)

# %%
pesos=np.random.random(num_stocks)
pesos/=np.sum(pesos)

# %%
pesos
# Out:
# array([0.07673001, 0.11796925, 0.27136804, 0.28132365, 0.25260905])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
np.sum(pesos*log_retornos.mean())*250
# Out:
# 0.850388889454197

# %% [markdown]
# # Calculo de la Varianza

# %%
np.dot(3,4)
# Out:
# 12

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a=[1,2]
b=[2,2]
np.dot(a,b)
# Out:
# 6

# %%
a=[[1,0],[0,1]]
b=[[4,1],[2,2]]
np.dot(a,b)
# Out:
# array([[4, 1],
#        [2, 2]])

# %%
x=np.array([[1.,2.],[3.,4.]])
print(x)
# Out:
# [[1. 2.]
#  [3. 4.]]

# %%
print(x.T)
# Out:
# [[1. 3.]
#  [2. 4.]]

# %%
varianza=np.dot(pesos.T,np.dot(log_retornos.cov()*250,pesos))

# %%
volatilidad=np.sqrt(varianza)
volatilidad
# Out:
# 0.40746175734864654

# %%
retornos_portafolio=[]
volatilidades_portafolio=[]
for x in range (1000):
  pesos=np.random.random(num_stocks)
  pesos/=np.sum(pesos)
  retornos_portafolio.append(np.sum(pesos*log_retornos.mean())*250)
  volatilidades_portafolio.append(np.sqrt(np.dot(pesos.T,np.dot(log_retornos.cov()*250,pesos))))

# %%
retornos_portafolio=np.array(retornos_portafolio)

# %%
volatilidades_portafolio=np.array(volatilidades_portafolio)

# %%
portafolios=pd.DataFrame({'retorno':retornos_portafolio,'volatilidad':volatilidades_portafolio})

# %%
portafolios.tail()
# Out:
#       retorno  volatilidad
# 995  0.715741     0.400993
# 996  0.735294     0.399628
# 997  0.711518     0.412414
# 998  0.831815     0.413644
# 999  0.569832     0.365045
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_1395605806156660703 = autoviz.get_registered_df('df_1395605806156660703')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_1395605806156660703, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_1395605806156660703 = autoviz.get_registered_df('df_1395605806156660703')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_1395605806156660703, *['retorno'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_1395605806156660703 = autoviz.get_registered_df('df_1395605806156660703')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_1395605806156660703, *['volatilidad'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_1395605806156660703 = autoviz.get_registered_df('df_1395605806156660703')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_1395605806156660703, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_1395605806156660703 = autoviz.get_registered_df('df_1395605806156660703')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_1395605806156660703, *['retorno'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_1395605806156660703 = autoviz.get_registered_df('df_1395605806156660703')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_1395605806156660703, *['volatilidad'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_1395605806156660703 = autoviz.get_registered_df('df_1395605806156660703')
#
# def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
#     plt.xlabel(x_colname)
#     plt.ylabel(y_colname)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df_1395605806156660703, *[[['index', 'retorno'], ['retorno', 'volatilidad']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_1395605806156660703 = autoviz.get_registered_df('df_1395605806156660703')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3)):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   def _plot_series(series, series_name):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name)
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for series_name, series in df.groupby(series_colname):
#       _plot_series(series, series_name)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_1395605806156660703, *['index', 'retorno', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_1395605806156660703 = autoviz.get_registered_df('df_1395605806156660703')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3)):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   def _plot_series(series, series_name):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name)
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for series_name, series in df.groupby(series_colname):
#       _plot_series(series, series_name)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_1395605806156660703, *['index', 'volatilidad', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_1395605806156660703 = autoviz.get_registered_df('df_1395605806156660703')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3)):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   def _plot_series(series, series_name):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name)
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for series_name, series in df.groupby(series_colname):
#       _plot_series(series, series_name)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_1395605806156660703, *['index', 'count()', None], **{})
# chart

# %%
portafolios.plot(x='volatilidad',y='retorno',kind='scatter',figsize=(10,6))
plt.xlabel('Volatilidad')
plt.ylabel('Retorno')
# Out:
# Text(0, 0.5, 'Retorno')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
